# %%
import pandas as pd

# %%
commit_summary = pd.read_csv('commit_summary.csv', escapechar='\\')
commit_summary.tail(5)
# Out:
#                                           Hash  \
# 1001  bd8d2fbc99214cb0e2ee1dc1f09ab7e960c7bc81
# 1002  a5a73cb2daa219e210b4c8541bef1f1f7f40a5a2
# 1003  778773074338d5214c9d2ad59b8689cc0b475c95
# 1004  e81dfab0e65d30e50675b3f3ff679bc26edb7a9d
# 1005  cc5fbe17b9df97cad82bc2054a4eda286d1e2ba4
#
#                                                 Message  \
# 1001  Update URL to pango in README.md (#2334)\n\nht...
# 1002  Fix typos in GLSL comments and add constants `...
# 1003  Fix No matching distribution found for audioop...
# 1004     Fixed minor typos in example_scenes.py (#2351)
# 1005               Fix bug with mirroring file prefixes
#
#                                  Hashes of Parents  Is a merge commit?  \
# 1001  ['53bc83d94a8763c6a4b5fcdaa653b1049511f01c']               False
# 1002  ['bd8d2fbc99214cb0e2ee1dc1f09ab7e960c7bc81']               False
# 1003  ['a5a73cb2daa219e210b4c8541bef1f1f7f40a5a2']               False
# ...

# %%
commits_files_diff = pd.read_csv('commit_files_diff.csv', escapechar='\\')
commits_files_diff.tail(5)
# Out:
#                                           Hash  \
# 1427  a5a73cb2daa219e210b4c8541bef1f1f7f40a5a2
# 1428  778773074338d5214c9d2ad59b8689cc0b475c95
# 1429  778773074338d5214c9d2ad59b8689cc0b475c95
# 1430  e81dfab0e65d30e50675b3f3ff679bc26edb7a9d
# 1431  cc5fbe17b9df97cad82bc2054a4eda286d1e2ba4
#
#                                                 Message           Filename  \
# 1427  Fix typos in GLSL comments and add constants `...          frag.glsl
# 1428  Fix No matching distribution found for audioop...   requirements.txt
# 1429  Fix No matching distribution found for audioop...          setup.cfg
# 1430     Fixed minor typos in example_scenes.py (#2351)  example_scenes.py
# 1431               Fix bug with mirroring file prefixes          config.py
#
#                                     Source code(before)  \
# 1427  #version 330\n\nuniform float glow_factor;\nun...
# 1428  addict\nappdirs\naudioop-lts\ncolour\ndiskcach...
# ...

# %%
data_with_llm_inferences = pd.read_csv('data_with_llm_inferences.csv', escapechar='\\')
data_with_llm_inferences.tail(5)
# Out:
#       Unnamed: 0                                      Hash  \
# 1427        1427  a5a73cb2daa219e210b4c8541bef1f1f7f40a5a2
# 1428        1428  778773074338d5214c9d2ad59b8689cc0b475c95
# 1429        1429  778773074338d5214c9d2ad59b8689cc0b475c95
# 1430        1430  e81dfab0e65d30e50675b3f3ff679bc26edb7a9d
# 1431        1431  cc5fbe17b9df97cad82bc2054a4eda286d1e2ba4
#
#                                                 Message           Filename  \
# 1427  Fix typos in GLSL comments and add constants `...          frag.glsl
# 1428  Fix No matching distribution found for audioop...   requirements.txt
# 1429  Fix No matching distribution found for audioop...          setup.cfg
# 1430     Fixed minor typos in example_scenes.py (#2351)  example_scenes.py
# 1431               Fix bug with mirroring file prefixes          config.py
#
#                                     Source code(before)  \
# 1427  #version 330\n\nuniform float glow_factor;\nun...
# ...

# %%
rectified = pd.read_csv("commits_with_rectified_msgs_(prefixes removed).csv", escapechar='\\')
rectified.tail(5)
# Out:
#       Unnamed: 0.1  Unnamed: 0                                      Hash  \
# 1427          1427        1427  a5a73cb2daa219e210b4c8541bef1f1f7f40a5a2
# 1428          1428        1428  778773074338d5214c9d2ad59b8689cc0b475c95
# 1429          1429        1429  778773074338d5214c9d2ad59b8689cc0b475c95
# 1430          1430        1430  e81dfab0e65d30e50675b3f3ff679bc26edb7a9d
# 1431          1431        1431  cc5fbe17b9df97cad82bc2054a4eda286d1e2ba4
#
#                                                 Message           Filename  \
# 1427  Fix typos in GLSL comments and add constants `...          frag.glsl
# 1428  Fix No matching distribution found for audioop...   requirements.txt
# 1429  Fix No matching distribution found for audioop...          setup.cfg
# 1430     Fixed minor typos in example_scenes.py (#2351)  example_scenes.py
# 1431               Fix bug with mirroring file prefixes          config.py
#
#                                     Source code(before)  \
# ...
